# %%
import pandas as pd
from surprise import Dataset, Reader, SVD
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
data = pd.read_csv("Preprocessed_data.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  user_id                   location      age        isbn  \
# 0           0        2  stockton, california, usa  18.0000  0195153448
# 1           1        8   timmins, ontario, canada  34.7439  0002005018
# 2           2    11400    ottawa, ontario, canada  49.0000  0002005018
# 3           3    11676              n/a, n/a, n/a  34.7439  0002005018
# 4           4    41385   sudbury, ontario, canada  34.7439  0002005018
#
#    rating           book_title           book_author  year_of_publication  \
# 0       0  Classical Mythology    Mark P. O. Morford               2002.0
# 1       5         Clara Callan  Richard Bruce Wright               2001.0
# 2       0         Clara Callan  Richard Bruce Wright               2001.0
# 3       8         Clara Callan  Richard Bruce Wright               2001.0
# 4       0         Clara Callan  Richard Bruce Wright               2001.0
#
#                  publisher                                              img_s  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 2    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 3    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 4    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                                img_m  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0002005018.0...
# 3  http://images.amazon.com/images/P/0002005018.0...
# 4  http://images.amazon.com/images/P/0002005018.0...
#
#                                                img_l  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0002005018.0...
# 3  http://images.amazon.com/images/P/0002005018.0...
# 4  http://images.amazon.com/images/P/0002005018.0...
#
#                                              Summary Language  \
# 0  Provides an introduction to classical myths pl...       en
# 1  In a small town in Canada, Clara Callan reluct...       en
# 2  In a small town in Canada, Clara Callan reluct...       en
# 3  In a small town in Canada, Clara Callan reluct...       en
# 4  In a small town in Canada, Clara Callan reluct...       en
#
#              Category      city       state country
# 0  ['Social Science']  stockton  california     usa
# 1       ['Actresses']   timmins     ontario  canada
# 2       ['Actresses']    ottawa     ontario  canada
# 3       ['Actresses']       NaN         NaN     NaN
# 4       ['Actresses']   sudbury     ontario  canada

# %%
data.drop(['Unnamed: 0',  'age', 
           'publisher','img_s', 'img_m', 'img_l', 'Summary', 'Language'], axis = 1, inplace = True)

# %%
data.head()
# Out:
#    user_id                   location        isbn  rating  \
# 0        2  stockton, california, usa  0195153448       0
# 1        8   timmins, ontario, canada  0002005018       5
# 2    11400    ottawa, ontario, canada  0002005018       0
# 3    11676              n/a, n/a, n/a  0002005018       8
# 4    41385   sudbury, ontario, canada  0002005018       0
#
#             book_title           book_author  year_of_publication  \
# 0  Classical Mythology    Mark P. O. Morford               2002.0
# 1         Clara Callan  Richard Bruce Wright               2001.0
# 2         Clara Callan  Richard Bruce Wright               2001.0
# 3         Clara Callan  Richard Bruce Wright               2001.0
# 4         Clara Callan  Richard Bruce Wright               2001.0
#
#              Category      city       state country
# 0  ['Social Science']  stockton  california     usa
# 1       ['Actresses']   timmins     ontario  canada
# 2       ['Actresses']    ottawa     ontario  canada
# 3       ['Actresses']       NaN         NaN     NaN
# 4       ['Actresses']   sudbury     ontario  canada

# %%
data.drop(['location',  'city', 
           'state','state', 'country'], axis = 1, inplace = True)

# %%
data.head()
# Out:
#    user_id        isbn  rating           book_title           book_author  \
# 0        2  0195153448       0  Classical Mythology    Mark P. O. Morford
# 1        8  0002005018       5         Clara Callan  Richard Bruce Wright
# 2    11400  0002005018       0         Clara Callan  Richard Bruce Wright
# 3    11676  0002005018       8         Clara Callan  Richard Bruce Wright
# 4    41385  0002005018       0         Clara Callan  Richard Bruce Wright
#
#    year_of_publication            Category
# 0               2002.0  ['Social Science']
# 1               2001.0       ['Actresses']
# 2               2001.0       ['Actresses']
# 3               2001.0       ['Actresses']
# 4               2001.0       ['Actresses']

# %%
# Collaborative Filtering Model (SVD)
reader = Reader(rating_scale=(0, 10))
data_surprise = Dataset.load_from_df(data[['user_id', 'isbn', 'rating']], reader)
trainset = data_surprise.build_full_trainset()
algo = SVD()
algo.fit(trainset)

# %%
# TF-IDF Vectorization for book titles
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(data['book_title'])

# %%
import random

def get_similar_books(book_title, n=5):
    # Find similar books based on collaborative filtering
    book_id = data[data['book_title'] == book_title]['isbn'].iloc[0]
    # Select a random user ID from the trainset
    user_id = random.choice(trainset.all_users())
    test_data = [(user_id, book_id, 0) for _ in range(algo.trainset.n_items)]  # Use the selected user ID and zero rating
    predictions = algo.test(test_data)  # Predict ratings for all items
    sim_books_collab = [pred.iid for pred in predictions]  # Extract item IDs
    
    # Find similar books based on title similarity
    book_idx = data[data['book_title'] == book_title].index[0]
    title_sim = cosine_similarity(tfidf_matrix[book_idx], tfidf_matrix)
    sim_books_title = [trainset.to_raw_iid(idx) for idx in title_sim.argsort()[0][-n-1:-1][::-1]]  # Convert indices to raw item IDs
    
    # Merge and deduplicate recommendations
    recommendations = list(set(sim_books_collab + sim_books_title))  # Convert set to list
    
    # Return book titles
    return data.loc[data['isbn'].isin(recommendations), 'book_title']

# %%
# Example usage
book_title_input = "Clara Callan"
recommended_books = get_similar_books(book_title_input)
print("Recommended books based on", book_title_input)
print(recommended_books)
# Out:
# Recommended books based on Clara Callan
# 1                                          Clara Callan
# 2                                          Clara Callan
# 3                                          Clara Callan
# 4                                          Clara Callan
# 5                                          Clara Callan
# 6                                          Clara Callan
# 7                                          Clara Callan
# 8                                          Clara Callan
# 9                                          Clara Callan
# 10                                         Clara Callan
# 11                                         Clara Callan
# 12                                         Clara Callan
# 13                                         Clara Callan
# 14                                         Clara Callan
# 68                                      PLEADING GUILTY
# 69                                      PLEADING GUILTY
# 70                                      PLEADING GUILTY
# 73                          Nights Below Station Street
# 74                          Nights Below Station Street
# 75                          Nights Below Station Street
# 76                          Nights Below Station Street
# 77                          Nights Below Station Street
# 78                          Nights Below Station Street
# 80                                   The Middle Stories
# 81                                   The Middle Stories
# 82                                             Jane Doe
# 83    A Second Chicken Soup for the Woman's Soul (Ch...
# 84    A Second Chicken Soup for the Woman's Soul (Ch...
# 85    A Second Chicken Soup for the Woman's Soul (Ch...
# 86    A Second Chicken Soup for the Woman's Soul (Ch...
# 87    A Second Chicken Soup for the Woman's Soul (Ch...
# 88    A Second Chicken Soup for the Woman's Soul (Ch...
# 89    A Second Chicken Soup for the Woman's Soul (Ch...
# 90    A Second Chicken Soup for the Woman's Soul (Ch...
# Name: book_title, dtype: object
